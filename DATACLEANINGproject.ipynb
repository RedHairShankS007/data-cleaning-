# %% [markdown]
# <a href="https://colab.research.google.com/github/RedHairShankS007/data-cleaning-/blob/main/DATACLEANINGproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HOW TO CREATE A DATA FRAME USING CSV

# %%
# modules we'll use
import pandas as pd
import numpy as np

# read in all our data
data_set1= "/cars_data.csv"
car_data = pd.read_csv(data_set1)

# set seed for reproducibility
np.random.seed(0)
# how to see dataset
car_data.head(10)
# Out:
#                      Exterior color                           Interior color  \
# 0                   Santorini Black                                    Ebony
# 1                        Fuji White                                    Ebony
# 2                    Tanzanite Blue                              Silverstone
# 3                       Polar White                                Macchiato
# 4                         Blueprint                                    Black
# 5  White Platinum Tri-Coat Metallic                                     Mesa
# 6            Galactic Gray Metallic                                   Brandy
# 7                              01H1                                     Gray
# 8               Eiger Grey Metallic  Light Oyster Perforated Grained Leather
# 9              White Frost Tri-Coat                              Light Shale
#
#          Drivetrain    MPG Fuel type        Transmission  \
# 0  Four-wheel Drive      –  Gasoline   8-Speed Automatic
# ...

# %% [markdown]
# Yep, it looks like there's some missing values.
#
# How many missing data points do we have?

# %%
# get the number of missing data points per column
missing_values_count = car_data.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# Exterior color      0
# Interior color      0
# Drivetrain          0
# MPG               334
# Fuel type         334
# Transmission        0
# Engine              0
# VIN                 0
# Stock #             0
# Mileage             0
# dtype: int64

# %% [markdown]
# That seems like a lot! It might be helpful to see what percentage of the values in our dataset were missing to give us a better sense of the scale of this problem:
#
# # how many total missing values do we have?

# %%
total_cells = np.product(car_data.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.8212340640021637

# %% [markdown]
# DROP MISSING VALUES

# %%
# remove all the rows that contain a missing value
car_data.dropna()
# Out:
#                      Exterior color  Interior color        Drivetrain    MPG  \
# 0                   Santorini Black           Ebony  Four-wheel Drive      –
# 1                        Fuji White           Ebony  Four-wheel Drive  18–23
# 2                    Tanzanite Blue     Silverstone   All-wheel Drive  16–23
# 3                       Polar White       Macchiato   All-wheel Drive  20–24
# 4                         Blueprint           Black  Four-wheel Drive  19–22
# ...                             ...             ...               ...    ...
# 6252         Selenite Gray Metallic           Black   All-wheel Drive  20–28
# 6253           White Frost Tri-Coat     Dark Walnut  Four-wheel Drive  14–18
# 6254                      Avalanche           Black               4WD  15–18
# 6255  Inferno Red Crystal Pearlcoat  Med Slate Gray  Four-wheel Drive    0–0
# 6256          Sonic Silver Metallic           Black   All-wheel Drive  22–27
#
#      Fuel type        Transmission  \
# ...

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = car_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#     Exterior color Interior color        Drivetrain        Transmission  \
# 0  Santorini Black          Ebony  Four-wheel Drive   8-Speed Automatic
# 1       Fuji White          Ebony  Four-wheel Drive           Automatic
# 2   Tanzanite Blue    Silverstone   All-wheel Drive   8-Speed Automatic
# 3      Polar White      Macchiato   All-wheel Drive   9-Speed Automatic
# 4        Blueprint          Black  Four-wheel Drive  10-Speed Automatic
#
#                                    Engine                VIN    Stock #  \
# 0       5.0L V8 32V GDI DOHC Supercharged  SALEPEFE0R2254092       4614
# 1              3.0L I6 24V GDI DOHC Turbo  SALE26EUXP2213494       4498
# 2         3.0L I6 24V GDI DOHC Twin Turbo  WBS33BA05RCP46785   RCP46785
# 3              2.0L I4 16V GDI DOHC Turbo  4JGFB4KB4PA915475  M20235475
# 4  3.4L V6 24V PDI DOHC Twin Turbo Hybrid  7SVAAABA1RX024167     240208
#
#      Mileage                                     title  primaly_price currency
# ...

# %% [markdown]
# TO CHECK HOW MUCH DATA WE LOSE AFTER DATA CLEANING

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % car_data.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 13
#
# Columns with na's dropped: 11
